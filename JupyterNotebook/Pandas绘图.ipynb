# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,100,num=1000)
# f = lambda x : (1-x**2)**0.5
s = Series(nd)
s.plot()

# plt.plot(x,f(x))

# %%
df = DataFrame(np.random.randint(0,150,size=(10,4)),columns=list('ABCD'),index=list('abcdefghjk'))
# df
df.plot()

# %%
df.plot(kind='bar')
df.plot(kind='barh')

# %%
game_data = pd.read_excel('../JupyterNotebook/taptaphot.xlsx')
game_data.head()
# Out:
#         游戏名称  游戏评分  游戏类型  安装、预约、购买人数      关注人数    游戏容量 容量单位     评论数
# 0       香肠派对   7.4    动作    18471768   4609888  443.30   MB   50364
# 1  绝地求生：刺激战场   8.3  角色扮演           0  10904687    1.80   GB  110580
# 2       王者荣耀   4.7    动作     9480921   9394576    1.38   GB   96428
# 3       明日之后   3.2  角色扮演     5057655   3455202    1.26   GB  194166
# 4       交叉线!   7.9    益智      581280    341455   24.52   MB    1004

# %%
game_data2 = game_data[['游戏类型','游戏评分','评论数']]
game_data3 = game_data2.set_index('游戏类型')
game_data3.plot()

# %%
nd1 = np.random.randint(0,150,size=30)
nd1
# Out:
# array([ 42, 103,  43, 101,  68,  54, 102,  94, 113,  85,   4,  93,  22,
#         62,  78,  69,  56, 141,  19, 137,  80,  56, 122,  86,  62,  67,
#         33,  20,  69, 148])

# %%
s1 =Series(nd1)

# %%
s1.hist()

# %%
nd3 = np.random.normal(65,10,size=150)
nd4 = np.random.normal(165,10,size=150)
nd5 = np.concatenate([nd3,nd4])
s3 = Series(nd5)

# %%
s3.hist(bins=100,normed=True)
s3.plot(kind='kde')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
